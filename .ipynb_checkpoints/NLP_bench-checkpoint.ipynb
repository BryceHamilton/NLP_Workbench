# %%
import numpy as np

#*** TRAINING ***
train_file = open('covid_training.tsv', 'r', encoding='utf-8')
tweets = {}
vocabulary = []

next(train_file) # skip header

for line in train_file:
    # split tsv lines
    split_line = line.split("\t")
    
    # get tweet data and fold to lower case
    tweet_id = split_line[0]
    tweet_text = split_line[1].lower()
    q_label = split_line[2]
    
    # get tweet text
    split_text = tweet_text.split(" ")
    tweet_vector = {}
    for token in split_text:
        # add term to tweet_vector and count frequency
        if token not in tweet_vector.keys():
            vocabulary.append(token)
            tweet_vector[token] = 1
        else:
            tweet_vector[token] += 1    
            
    # add tweet vector and label to tweets dictionary
    tweets[tweet_id] = (tweet_vector, q_label)
    
# no duplicates
vocabulary = sorted(set(vocabulary))
#print(vocabulary)

# %%
# tweets directory{}, and vocabulary list[]
for i in tweets:
    if tweets[i][1] == "yes":
        print(tuple(list(tweets[i][0].keys())))
        print(tweets[i][1])
        
print(len(tweets))
    
#print(len(vocabulary))
#print(vocabulary)
# Out:
# ('this', 'is', 'the', 'face', 'of', 'someone', 'who', 'just', 'spent', '9', 'hours', 'in', 'personal', 'protective', 'equipment', 'moving', 'critically', 'ill', 'covid19', 'patients', 'around', 'london.', '', 'i', 'feel', 'broken', '-', 'and', 'we', 'are', 'only', 'at', 'start.', 'am', 'begging', 'people,', 'please', 'do', 'social', 'distancing', 'self', 'isolation', '#covid19', 'https://t.co/hs0rqdvsn3')
# yes
# ('yesterday', 'i', 'knocked', 'on', 'my', "tennant's", 'door', 'and', 'told', 'him', 'he', 'can', 'stay', 'in', 'the', 'property', 'rent', 'free', 'for', '5', 'months.', 'is', 'self', 'employed', 'with', '4', 'kids.', "don't", 'need', 'boris', 'to', 'tell', 'me', 'what', 'morally', 'correct.', 'landlords,', 'if', 'you', 'can,', 'do', 'more,', 'something.', '#covid19', '#benice')
# yes
# ...

# %%
# *** Compute Probabilities and TESTING ***

#0. Count the unique set of words present in each class
count_c1 = 0 # number of unique words present when class is 'yes' - will be used in the conditional probabilities
words_c1 = [] # with duplicates
set_words_c1 = []
instances_c1 = 0 # number of data instances with class 'yes'
for i in tweets:
    # c1: Check each tweet where q1 label=yes
    if tweets[i][1] == "yes":
        instances_c1+=1
        words = list(tweets[i][0].keys())
        for word in words:
            words_c1.append(word)   
set_words_c1 = set(words_c1) # no duplicates
count_c1 = len(set_words_c1)
print(words_c1)
print(count_c1)
print(instances_c1)

count_c2 = 0 # number of unique words present when class is 'no' - will be used in the conditional probabilities
words_c2 = []  # with duplicates
set_words_c2 = []
instances_c2 = 0 # number of data instances with class 'no'
for i in tweets:
    # c2: Check each tweet where q1 label=no
    if tweets[i][1] == "no":
        instances_c2+=1
        words = list(tweets[i][0].keys())
        for word in words:
            words_c2.append(word)   
set_words_c2 = set(words_c2) # no duplicates
count_c2 = len(set_words_c2)
print(words_c2)
print(count_c2)
print(instances_c2)

#1. Prior Probabilities
# How many instances of that class, over all the tweets
number_tweets = len(tweets)

priorprob_c1 = instances_c1/number_tweets
priorprob_c2 = instances_c2/number_tweets


#2. Conditional Probabilities and TEST data
# How many times a word appears in a particular class, for each class, and each word in the vocabulary
# USE: vocabulary[], words_c1 and words_c2 (words_c1, words_c2 keep track of frequencies of words)
# don't compute all the conditional probabilities... only do so when calling function score(c1) when testing new tweet
test_example = 'Panic buying and stockpiling of toilet roll continues. These are the scenes at Costco in Farnborough in Hampshire today. #coronavirus #toiletpaperpanic #panickbuying https://t.co/JLlZVVS7EH'
splited_text = test_example.split(" ")

# notice that some words in the sentence may not be part of the vocabulary
# SCORE(c1) - 'yes'
conditionalprob_c1 = []
for word in splited_text:
    if word in vocabulary: #find the conditional probability of this word 
        
        

# SCORE(c2) - 'no'
conditionalprob_c2 = []
# Out:
#   File "<ipython-input-11-d8f801488f77>", line 62
#     conditionalprob_c2 = 0
#                           ^
# IndentationError: expected an indented block
